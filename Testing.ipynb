# %%
import pandas as pd

# %%
df = pd.read_csv("labels.csv")

# %%
df
# Out:
#        patientunitstayid  predictedhospitalmortality actualhospitalmortality  \
# 0                 141265                    0.052292                   ALIVE
# 1                 141650                    0.098379                   ALIVE
# 2                 141806                    0.613244                   ALIVE
# 3                 141920                    0.122093                   ALIVE
# 4                 142096                    0.023930                   ALIVE
# ...                  ...                         ...                     ...
# 89118            3352643                    0.096242                   ALIVE
# 89119            3352737                    0.644352                 EXPIRED
# 89120            3352883                    0.065109                   ALIVE
# 89121            3353044                    0.020046                   ALIVE
# 89122            3353113                    0.007091                   ALIVE
#
#        predictediculos  actualiculos
# ...

# %%
df.loc[df['patientunitstayid'] == 3352441]
# Out:
# Empty DataFrame
# Columns: [patientunitstayid, predictedhospitalmortality, actualhospitalmortality, predictediculos, actualiculos]
# Index: []
